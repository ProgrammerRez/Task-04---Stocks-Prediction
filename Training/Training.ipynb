# %% [markdown]
# ## Collecting and Arranging the Data

# %%
import yfinance as yf
import pandas as pd

def download_and_combine(tickers, period='20y'):
    all_data = []

    for ticker in tickers:
        # Download data
        df = yf.download([ticker], period=period, group_by='Ticker')

        # Flatten MultiIndex columns
        df.columns = [col[1] for col in df.columns]

        # Add ticker column
        df['ticker'] = ticker

        # Store for combining
        all_data.append(df)

    # Combine all tickers into one dataframe
    combined_df = pd.concat(all_data).reset_index()

    return combined_df

tickers = ['AAPL', 'MSFT', 'GOOGL']
df = download_and_combine(tickers)

df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25128\521353212.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download([ticker], period=period, group_by='Ticker')
# [*********************100%***********************]  1 of 1 completed
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25128\521353212.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download([ticker], period=period, group_by='Ticker')
# [*********************100%***********************]  1 of 1 completed
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25128\521353212.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download([ticker], period=period, group_by='Ticker')
# [*********************100%***********************]  1 of 1 completed
#             Date        Open        High         Low       Close      Volume  \
# 0     2005-11-22    1.944618    2.002202    1.935022    1.995004   540282400
# 1     2005-11-23    2.005801    2.038791    2.000103    2.012699   485853200
# 2     2005-11-25    2.029195    2.085577    2.024395    2.079580   395012800
# 3     2005-11-28    2.120966    2.131463    2.071482    2.089176  1018519600
# 4     2005-11-29    2.099073    2.108370    2.019896    2.042390   891433200
# ...          ...         ...         ...         ...         ...         ...
# 15091 2025-11-17  285.779999  293.950012  283.570007  285.019989    52670200
# 15092 2025-11-18  287.920013  288.799988  278.200012  284.279999    49158700
# 15093 2025-11-19  287.160004  303.809998  286.630005  292.809998    68198900
# 15094 2025-11-20  304.540009  306.420013  288.670013  289.450012    62025200
# 15095 2025-11-21  296.420013  303.920013  293.850006  299.660004    73945800
#
#       ticker
# 0       AAPL
# 1       AAPL
# 2       AAPL
# 3       AAPL
# 4       AAPL
# ...      ...
# 15091  GOOGL
# 15092  GOOGL
# 15093  GOOGL
# 15094  GOOGL
# 15095  GOOGL
#
# [15096 rows x 7 columns]

# %% [markdown]
# ## Visualizing the Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df1 = df.copy()
df1['Year'] = df1['Date'].dt.year
df1['Month'] = df1['Date'].dt.month
df1['Day'] = df1['Date'].dt.day


plt.figure(figsize=(15,9))
sns.lineplot(data=df1,x='Year',y='Close',hue='ticker')
# Out:
# <Axes: xlabel='Year', ylabel='Close'>

# %%
plt.figure(figsize=(15,9))
sns.lineplot(data=df1,x='Year',y='Volume',hue='ticker')
# Out:
# <Axes: xlabel='Year', ylabel='Volume'>

# %%
plt.figure(figsize=(15,9))
sns.lineplot(data=df1,x='Year',y='Open',hue='ticker')
# Out:
# <Axes: xlabel='Year', ylabel='Open'>

# %% [markdown]
# ## Feature Engineering

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
df2 = df.copy()
le = LabelEncoder()

df2['ticker'] = le.fit_transform(df2['ticker'])
df2
# Out:
#             Date        Open        High         Low       Close      Volume  \
# 0     2005-11-21    1.944020    1.955116    1.911029    1.948218   511711200
# 1     2005-11-22    1.944619    2.002202    1.935023    1.995004   540282400
# 2     2005-11-23    2.005800    2.038790    2.000102    2.012698   485853200
# 3     2005-11-25    2.029194    2.085577    2.024395    2.079579   395012800
# 4     2005-11-28    2.120967    2.131464    2.071482    2.089176  1018519600
# ...          ...         ...         ...         ...         ...         ...
# 15088 2025-11-13  282.339996  282.839996  277.239990  278.570007    29494000
# 15089 2025-11-14  271.410004  278.559998  270.700012  276.410004    31647200
# 15090 2025-11-17  285.779999  293.950012  283.570007  285.019989    52670200
# 15091 2025-11-18  287.920013  288.799988  278.200012  284.279999    49158700
# 15092 2025-11-19  287.160004  303.809998  286.630005  292.809998    67992000
#
#        ticker
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 15088       1
# 15089       1
# 15090       1
# 15091       1
# 15092       1
#
# [15093 rows x 7 columns]

# %%
df2['Year'] = df2['Date'].dt.year
df2['Month'] = df2['Date'].dt.month
df2['Day'] = df2['Date'].dt.day

df2 = df2.drop(['Date'],axis=1)
df2
# Out:
#              Open        High         Low       Close      Volume  ticker  \
# 0        1.944020    1.955116    1.911029    1.948218   511711200       0
# 1        1.944619    2.002202    1.935023    1.995004   540282400       0
# 2        2.005800    2.038790    2.000102    2.012698   485853200       0
# 3        2.029194    2.085577    2.024395    2.079579   395012800       0
# 4        2.120967    2.131464    2.071482    2.089176  1018519600       0
# ...           ...         ...         ...         ...         ...     ...
# 15088  282.339996  282.839996  277.239990  278.570007    29494000       1
# 15089  271.410004  278.559998  270.700012  276.410004    31647200       1
# 15090  285.779999  293.950012  283.570007  285.019989    52670200       1
# 15091  287.920013  288.799988  278.200012  284.279999    49158700       1
# 15092  287.160004  303.809998  286.630005  292.809998    67992000       1
#
#        Year  Month  Day
# 0      2005     11   21
# 1      2005     11   22
# 2      2005     11   23
# 3      2005     11   25
# 4      2005     11   28
# ...     ...    ...  ...
# 15088  2025     11   13
# 15089  2025     11   14
# 15090  2025     11   17
# 15091  2025     11   18
# 15092  2025     11   19
#
# [15093 rows x 9 columns]

# %% [markdown]
# ## Model Training and Evaluation

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
scaler = StandardScaler()
X = df2.drop(['Close'],axis=1)
y = df2.Close

X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled,y,test_size=0.2)

# %%
kf = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet

param_grid = [
    {
        'model': [LinearRegression()],
        'model__fit_intercept': [True, False],
        'model__positive': [False]   
    },
    {
        'model': [Ridge()],
        'model__alpha': [0.1, 1, 10, 50, 100]
    },
    {
        'model': [Lasso(max_iter=5000)],
        'model__alpha': [0.0001, 0.001, 0.01, 0.1, 1]
    },
    {
        'model': [ElasticNet(max_iter=5000)],
        'model__alpha': [0.0001, 0.001, 0.01, 0.1, 1],
        'model__l1_ratio': [0.1, 0.5, 0.9]
    }
]

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ('model', LinearRegression())   # Placeholder, overwritten by GridSearchCV
])

# %%
grid = GridSearchCV(
    estimator=pipe,
    param_grid=param_grid,
    cv=kf,
    scoring='neg_mean_squared_error',  # or r2, mae, etc.
    n_jobs=-1,
    verbose=2
)

grid.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 27 candidates, totalling 270 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('model', LinearRegression())]),
#              n_jobs=-1,
#              param_grid=[{'model': [LinearRegression()],
#                           'model__fit_intercept': [True, False],
#                           'model__positive': [False]},
#                          {'model': [Ridge()],
#                           'model__alpha': [0.1, 1, 10, 50, 100]},
#                          {'model': [Lasso(max_iter=5000)],
#                           'model__alpha': [0.0001, 0.001, 0.01, 0.1, 1]},
#                          {'model': [ElasticNet(max_iter=5000)],
#                           'model__alpha': [0.0001, 0.001, 0.01, 0.1, 1],
#                           'model__l1_ratio': [0.1, 0.5, 0.9]}],
#              scoring='neg_mean_squared_error', verbose=2)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_pred = grid.predict(X_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 0.3664373985888762
# MSE: 0.4968624646726236
# RMSE: 0.4968624646726236
# R2 Score: 0.9999540655310766

# %% [markdown]
# ## Saving the Data, Model, Scaler and Encoder

# %%
import pickle as pc
import os

os.makedirs('Data',exist_ok=True)
os.makedirs('Encoders',exist_ok=True)
os.makedirs('Models',exist_ok=True)
os.makedirs('Scaler',exist_ok=True)

# %%
with open('Models/model.pkl','wb') as f:
    pc.dump(grid,f)
    
with open('Scaler/scaler.pkl','wb') as f:
    pc.dump(scaler,f)
    
with open('encoders/encoder.pkl','wb') as f:
    pc.dump(le,f)
    

df1.to_csv('Data/data.csv',index=0)

# %%
print(df1.columns)
print(df1.ticker.unique())
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'ticker', 'Year',
#        'Month', 'Day'],
#       dtype='object')
# ['AAPL' 'MSFT' 'GOOGL']

# %%
# Out:
# array(['AAPL', 'MSFT', 'GOOGL'], dtype=object)
